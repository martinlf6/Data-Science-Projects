# %%
pip install dash jupyter-dash plotly jupyterlab jupyterlab-dash
# Out:
# Requirement already satisfied: dash in c:\users\feng liu\anaconda3\lib\site-packages (3.0.4)
# Requirement already satisfied: jupyter-dash in c:\users\feng liu\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: plotly in c:\users\feng liu\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: jupyterlab in c:\users\feng liu\anaconda3\lib\site-packages (3.6.3)
# Requirement already satisfied: jupyterlab-dash in c:\users\feng liu\anaconda3\lib\site-packages (0.1.0a3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: importlib-metadata in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (6.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (4.7.1)
# Requirement already satisfied: requests in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: setuptools in c:\users\feng liu\anaconda3\lib\site-packages (from dash) (68.0.0)
# Requirement already satisfied: ipython in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-dash) (8.15.0)
# Requirement already satisfied: ipykernel in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-dash) (6.25.0)
# Requirement already satisfied: ansi2html in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\feng liu\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (23.1)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (6.3.2)
# Requirement already satisfied: jupyter-core in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (5.3.0)
# Requirement already satisfied: jupyterlab-server~=2.19 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (2.22.0)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (2.16.0)
# Requirement already satisfied: jupyter-ydoc~=0.2.3 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (0.8.0)
# Requirement already satisfied: nbclassic in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (0.5.5)
# Requirement already satisfied: notebook<7 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (6.5.4)
# Requirement already satisfied: jinja2>=2.1 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab) (3.1.2)
# Requirement already satisfied: jupyter-server-proxy in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab-dash) (4.4.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\feng liu\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\feng liu\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (3.5.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.4.9)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (6.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.7.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-core->jupyterlab) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab) (0.9.0)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab) (0.8.2)
# Requirement already satisfied: y-py<0.6.0,>=0.5.3 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-ydoc~=0.2.3->jupyterlab) (0.5.9)
# Requirement already satisfied: babel>=2.10 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab) (0.9.6)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyterlab-server~=2.19->jupyterlab) (4.24.0)
# Requirement already satisfied: ipython-genutils in c:\users\feng liu\anaconda3\lib\site-packages (from notebook<7->jupyterlab) (0.2.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\feng liu\anaconda3\lib\site-packages (from nbclassic->jupyterlab) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\feng liu\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\feng liu\anaconda3\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\feng liu\anaconda3\lib\site-packages (from requests->dash) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\feng liu\anaconda3\lib\site-packages (from requests->dash) (2023.7.22)
# Requirement already satisfied: zipp>=0.5 in c:\users\feng liu\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.11.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\feng liu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\feng liu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\feng liu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: psutil in c:\users\feng liu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: backcall in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: decorator in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: colorama in c:\users\feng liu\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.6)
# Requirement already satisfied: aiohttp in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server-proxy->jupyterlab-dash) (3.8.5)
# Requirement already satisfied: simpervisor>=1.0.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-server-proxy->jupyterlab-dash) (1.0.0)
# Requirement already satisfied: six>=1.7.0 in c:\users\feng liu\anaconda3\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\feng liu\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (1.2.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\feng liu\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\feng liu\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server~=2.19->jupyterlab) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (0.25.1)
# Requirement already satisfied: entrypoints in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\feng liu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab) (0.1.1)
# Requirement already satisfied: lxml in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.12.2)
# Requirement already satisfied: bleach in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\feng liu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\feng liu\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\feng liu\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in c:\users\feng liu\anaconda3\lib\site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in c:\users\feng liu\anaconda3\lib\site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab) (0.18.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\feng liu\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\feng liu\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\feng liu\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\feng liu\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\feng liu\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash) (1.2.0)
# Requirement already satisfied: executing in c:\users\feng liu\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\feng liu\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\feng liu\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (2.1)
# Requirement already satisfied: uri-template in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\feng liu\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\feng liu\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\feng liu\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.4)
# Requirement already satisfied: webencodings in c:\users\feng liu\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\feng liu\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\feng liu\anaconda3\lib\site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required libraries
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

import io
import requests

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
#resp = await fetch(URL)
#spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
#spacex_df=pd.read_csv(spacex_csv_file)

response = requests.get(URL)
csv_data = io.StringIO(response.text)
spacex_df = pd.read_csv(csv_data)

# Read the airline data into pandas dataframe
#spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',  options=[
                    {'label': 'All Sites', 'value': 'ALL'},
                    {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                    {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                    {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                    {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                ],
                value='ALL',
                placeholder="Select a Launch Site here",
                searchable=True),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',min=0, max=10000, step=1000,
                                marks={0: '0',100: '100'},value=[2500, 7800]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart'))
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
# Function decorator to specify function input and output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Total Success Launches By Site')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        fig = px.pie(filtered_df,  
        names='class', 
        title='Total Success Launches for site '+ entered_site)
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
# Function decorator to specify function input and output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'),
               Input(component_id="payload-slider", component_property="value")])
def get_scatter_chart(entered_site, slider_range):
    filtered_df = spacex_df
    low, high = slider_range
    mask = (filtered_df['Payload Mass (kg)'] > low) & (filtered_df['Payload Mass (kg)'] < high)
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df[mask], x='Payload Mass (kg)', y='class',
        color='Booster Version')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        mask = (filtered_df['Payload Mass (kg)'] > low) & (filtered_df['Payload Mass (kg)'] < high)
        fig = px.scatter(filtered_df[mask], x='Payload Mass (kg)', y='class',
        color='Booster Version')
        return fig

# Run the app (change the port number if showing the port is already used)
if __name__ == '__main__':
    app.run(port=8052)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# C:\Users\Feng Liu\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\Feng Liu\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\Feng Liu\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\Feng Liu\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\Feng Liu\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\Feng Liu\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
